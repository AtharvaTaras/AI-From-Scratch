# %% [markdown]
# Part 9 Version 2
# Larger datasets with output plots

# %%
import numpy as np
import matplotlib.pyplot as plt
import nnfs
from nnfs.datasets import vertical_data, spiral_data

# %%
nnfs.init()

# %%
X, y = vertical_data(samples=500, classes=3)

# %%
plt.figure(figsize=(12, 12))
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap='brg')
plt.show()

# %%
class Layer_Dense:
    
    def __init__(self, n_inputs, n_neurons):
        self.weights = 0.1 * np.random.randn(n_inputs, n_neurons)
        self.biases = np.zeros((1, n_neurons))
    
    def forward(self, inputs):
        self.output = np.dot(inputs, self.weights) + self.biases


class Activation_ReLU:
    
    def forward(self, inputs):
        self.output = np.maximum(0, inputs)

        
class Activation_Softmax:
    
    def forward(self, inputs):
        exp_values = np.exp(inputs - np.max(inputs, axis=1, keepdims=True))
        probabilities = exp_values / np.sum(exp_values, axis=1, keepdims=True)
        self.output = probabilities
        
        
class Loss:
    
    def calculate(self, output, y):
        sample_losses = self.forward(output, y)
        data_loss = np.mean(sample_losses)
        return data_loss

    
# catagorical cross entropy
class Loss_CatCrossEntropy(Loss):
    
    def forward(self, y_pred, y_true):
        samples = len(y_pred)
        y_pred_clip = np.clip(y_pred, 1e-7, 1-1e-7)
        
        # for one hot encoded vectors
        if len(y_true.shape) == 1:
            correct_conf = y_pred_clip[range(samples), y_true]
            
        elif len(y_true.shape) == 2:
            correct_conf = np.sum(y_pred_clip*y_true, axis=1)
            
        negative_log_likelihood = -np.log(correct_conf)
        return negative_log_likelihood

# %%
dense1 = Layer_Dense(2,3)
activation1 = Activation_ReLU()

dense2 = Layer_Dense(3, 3)
activation2 = Activation_Softmax()

dense1.forward(X)
activation1.forward(dense1.output)

dense2.forward(activation1.output)
activation2.forward(dense2.output)

loss_function = Loss_CatCrossEntropy()

lowest_loss = 9999999

best_dense1_weights = dense1.weights.copy()
best_dense1_biases = dense1.biases.copy()

best_dense2_weights = dense2.weights.copy()
best_dense2_biases = dense2.biases.copy()

# %%
iter_list = []
loss_list = []
accr_list = []

for iteration in range(500000):
    
    dense1.weights += 0.05 * np.random.randn(2, 3)
    dense1.biases += 0.05 * np.random.randn(1, 3)
    
    dense2.weights += 0.05 * np.random.randn(3, 3)
    dense2.biases += 0.05 * np.random.randn(1, 3)
    
    dense1.forward(X)
    activation1.forward(dense1.output)
    
    dense2.forward(activation1.output)
    activation2.forward(dense2.output)
    
    loss = loss_function.calculate(activation2.output, y)
    
    predictions = np.argmax(activation2.output, axis=1)
    accuracy = np.mean(predictions==y)
    
    if loss < lowest_loss:
        
        print('New set of weights found, iteration', iteration,
              'loss:', loss, 'accuracy', accuracy)
        
        best_dense1_weights = dense1.weights.copy()
        best_dense1_biases = dense1.biases.copy()
        
        best_dense2_weights = dense2.weights.copy()
        best_dense2_biases = dense2.biases.copy()
        
        lowest_loss = loss
        
        iter_list.append(iteration)
        loss_list.append(loss)
        accr_list.append(accuracy)
        
    else:
        
        dense1.weights = best_dense1_weights.copy()
        dense1.biases = best_dense1_biases.copy()
        
        dense2.weights = best_dense2_weights.copy()
        dense2.biases = best_dense2_biases.copy()
# Out:
# New set of weights found, iteration 0 loss: 1.1025486 accuracy 0.3333333333333333
# New set of weights found, iteration 1 loss: 1.1009333 accuracy 0.3333333333333333
# New set of weights found, iteration 5 loss: 1.1004109 accuracy 0.22466666666666665
# New set of weights found, iteration 6 loss: 1.0996058 accuracy 0.3333333333333333
# New set of weights found, iteration 9 loss: 1.0986971 accuracy 0.3333333333333333
# New set of weights found, iteration 10 loss: 1.096353 accuracy 0.3333333333333333
# New set of weights found, iteration 13 loss: 1.0957227 accuracy 0.3333333333333333
# New set of weights found, iteration 15 loss: 1.0936863 accuracy 0.3333333333333333
# New set of weights found, iteration 17 loss: 1.0910667 accuracy 0.3333333333333333
# New set of weights found, iteration 19 loss: 1.0906835 accuracy 0.3333333333333333
# New set of weights found, iteration 21 loss: 1.0900483 accuracy 0.3333333333333333
# New set of weights found, iteration 28 loss: 1.0833329 accuracy 0.34933333333333333
# New set of weights found, iteration 29 loss: 1.082604 accuracy 0.336
# New set of weights found, iteration 31 loss: 1.0792617 accuracy 0.5706666666666667
# New set of weights found, iteration 43 loss: 1.0787065 accuracy 0.4846666666666667
# New set of weights found, iteration 49 loss: 1.076352 accuracy 0.34
# New set of weights found, iteration 50679 loss: 0.15278615 accuracy 0.94
# New set of weights found, iteration 51591 loss: 0.15278365 accuracy 0.9393333333333334
# New set of weights found, iteration 53325 loss: 0.15276419 accuracy 0.9406666666666667
# New set of weights found, iteration 58315 loss: 0.15276198 accuracy 0.9393333333333334
# New set of weights found, iteration 60639 loss: 0.15275662 accuracy 0.9393333333333334
# New set of weights found, iteration 64533 loss: 0.15275049 accuracy 0.9406666666666667
# New set of weights found, iteration 67384 loss: 0.1527435 accuracy 0.9406666666666667
# New set of weights found, iteration 82184 loss: 0.15274331 accuracy 0.94
# New set of weights found, iteration 102609 loss: 0.1527378 accuracy 0.9413333333333334
# New set of weights found, iteration 168877 loss: 0.15273502 accuracy 0.9393333333333334
# New set of weights found, iteration 221167 loss: 0.15273428 accuracy 0.9393333333333334
# New set of weights found, iteration 341924 loss: 0.15272689 accuracy 0.9393333333333334
# New set of weights found, iteration 381627 loss: 0.15272297 accuracy 0.9393333333333334

# %%
plt.figure(figsize=(18, 9))
x1 = iter_list[:300]
y1 = accr_list[:300]
plt.plot(x1, y1, label = "Accuracy", linewidth='2')


x2 = iter_list[:300]
y2 = loss_list[:300]
plt.plot(x2, y2, label = "Loss", linewidth='2')


plt.xlabel('Iterations')
plt.ylabel('Value')


plt.title('Linear Dataset Plot')
plt.legend()
plt.show()

# %%
max(accr_list)
# Out:
# 0.9413333333333334

# %%
min(loss_list)
# Out:
# 0.15272297

# %%
X, y = spiral_data(samples=1000, classes=3)

# %%
plt.figure(figsize=(12, 12))
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap='brg')
plt.show()

# %%
class Layer_Dense:
    
    def __init__(self, n_inputs, n_neurons):
        self.weights = 0.1 * np.random.randn(n_inputs, n_neurons)
        self.biases = np.zeros((1, n_neurons))
    
    def forward(self, inputs):
        self.output = np.dot(inputs, self.weights) + self.biases


class Activation_ReLU:
    
    def forward(self, inputs):
        self.output = np.maximum(0, inputs)

        
class Activation_Softmax:
    
    def forward(self, inputs):
        exp_values = np.exp(inputs - np.max(inputs, axis=1, keepdims=True))
        probabilities = exp_values / np.sum(exp_values, axis=1, keepdims=True)
        self.output = probabilities
        
        
class Loss:
    
    def calculate(self, output, y):
        sample_losses = self.forward(output, y)
        data_loss = np.mean(sample_losses)
        return data_loss

    
# catagorical cross entropy
class Loss_CatCrossEntropy(Loss):
    
    def forward(self, y_pred, y_true):
        samples = len(y_pred)
        y_pred_clip = np.clip(y_pred, 1e-7, 1-1e-7)
        
        # for one hot encoded vectors
        if len(y_true.shape) == 1:
            correct_conf = y_pred_clip[range(samples), y_true]
            
        elif len(y_true.shape) == 2:
            correct_conf = np.sum(y_pred_clip*y_true, axis=1)
            
        negative_log_likelihood = -np.log(correct_conf)
        return negative_log_likelihood

# %%
dense1 = Layer_Dense(2,3)
activation1 = Activation_ReLU()

dense2 = Layer_Dense(3, 3)
activation2 = Activation_Softmax()

dense1.forward(X)
activation1.forward(dense1.output)

dense2.forward(activation1.output)
activation2.forward(dense2.output)

loss_function = Loss_CatCrossEntropy()

lowest_loss = 9999999

best_dense1_weights = dense1.weights.copy()
best_dense1_biases = dense1.biases.copy()

best_dense2_weights = dense2.weights.copy()
best_dense2_biases = dense2.biases.copy()

# %%
iter_list = []
loss_list = []
accr_list = []

for iteration in range(500000):
    
    dense1.weights += 0.05 * np.random.randn(2, 3)
    dense1.biases += 0.05 * np.random.randn(1, 3)
    
    dense2.weights += 0.05 * np.random.randn(3, 3)
    dense2.biases += 0.05 * np.random.randn(1, 3)
    
    dense1.forward(X)
    activation1.forward(dense1.output)
    
    dense2.forward(activation1.output)
    activation2.forward(dense2.output)
    
    loss = loss_function.calculate(activation2.output, y)
    
    predictions = np.argmax(activation2.output, axis=1)
    accuracy = np.mean(predictions==y)
    
    if loss < lowest_loss:
        
        print('New set of weights found, iteration', iteration,
              'loss:', loss, 'accuracy', accuracy)
        
        best_dense1_weights = dense1.weights.copy()
        best_dense1_biases = dense1.biases.copy()
        
        best_dense2_weights = dense2.weights.copy()
        best_dense2_biases = dense2.biases.copy()
        
        lowest_loss = loss
        
        iter_list.append(iteration)
        loss_list.append(loss)
        accr_list.append(accuracy)
        
    else:
        
        dense1.weights = best_dense1_weights.copy()
        dense1.biases = best_dense1_biases.copy()
        
        dense2.weights = best_dense2_weights.copy()
        dense2.biases = best_dense2_biases.copy()
# Out:
# New set of weights found, iteration 0 loss: 1.0979422 accuracy 0.3333333333333333
# New set of weights found, iteration 1 loss: 1.0978171 accuracy 0.37
# New set of weights found, iteration 4 loss: 1.0975657 accuracy 0.3333333333333333
# New set of weights found, iteration 6 loss: 1.0975254 accuracy 0.3333333333333333
# New set of weights found, iteration 7 loss: 1.0972751 accuracy 0.37266666666666665
# New set of weights found, iteration 13 loss: 1.0971621 accuracy 0.3343333333333333
# New set of weights found, iteration 22 loss: 1.0965109 accuracy 0.37333333333333335
# New set of weights found, iteration 24 loss: 1.0958813 accuracy 0.37233333333333335
# New set of weights found, iteration 30 loss: 1.0957783 accuracy 0.3616666666666667
# New set of weights found, iteration 34 loss: 1.094557 accuracy 0.37033333333333335
# New set of weights found, iteration 37 loss: 1.0931873 accuracy 0.38966666666666666
# New set of weights found, iteration 40 loss: 1.0930148 accuracy 0.35933333333333334
# New set of weights found, iteration 49 loss: 1.0909815 accuracy 0.4013333333333333
# New set of weights found, iteration 54 loss: 1.090955 accuracy 0.37166666666666665
# New set of weights found, iteration 57 loss: 1.0897413 accuracy 0.39866666666666667
# New set of weights found, iteration 63 loss: 1.0897051 accuracy 0.3546666666666667
# New set of weights found, iteration 65 loss: 1.088288 accuracy 0.3473333333333333
# New set of weights found, iteration 66 loss: 1.0879815 accuracy 0.39466666666666667
# New set of weights found, iteration 68 loss: 1.0867101 accuracy 0.39066666666666666
# New set of weights found, iteration 70 loss: 1.0855682 accuracy 0.403
# New set of weights found, iteration 75 loss: 1.0855622 accuracy 0.3913333333333333
# New set of weights found, iteration 76 loss: 1.0852786 accuracy 0.35533333333333333
# New set of weights found, iteration 82 loss: 1.0850208 accuracy 0.389
# New set of weights found, iteration 87 loss: 1.0841761 accuracy 0.404
# New set of weights found, iteration 89 loss: 1.0835755 accuracy 0.399
# New set of weights found, iteration 97 loss: 1.0827347 accuracy 0.37633333333333335
# New set of weights found, iteration 98 loss: 1.0822684 accuracy 0.3903333333333333
# New set of weights found, iteration 101 loss: 1.0812291 accuracy 0.389
# New set of weights found, iteration 102 loss: 1.0801105 accuracy 0.3863333333333333
# New set of weights found, iteration 110 loss: 1.080066 accuracy 0.403
# New set of weights found, iteration 113 loss: 1.0799601 accuracy 0.3626666666666667
# New set of weights found, iteration 115 loss: 1.0779558 accuracy 0.43266666666666664
# New set of weights found, iteration 140 loss: 1.0776885 accuracy 0.378
# New set of weights found, iteration 141 loss: 1.0775217 accuracy 0.39166666666666666
# New set of weights found, iteration 143 loss: 1.0771948 accuracy 0.42
# New set of weights found, iteration 146 loss: 1.077071 accuracy 0.425
# New set of weights found, iteration 150 loss: 1.0766687 accuracy 0.4053333333333333
# New set of weights found, iteration 187 loss: 1.0764961 accuracy 0.41733333333333333
# New set of weights found, iteration 196 loss: 1.0762274 accuracy 0.418
# New set of weights found, iteration 197 loss: 1.0762058 accuracy 0.4096666666666667
# New set of weights found, iteration 207 loss: 1.0756799 accuracy 0.39866666666666667
# New set of weights found, iteration 208 loss: 1.0755379 accuracy 0.4013333333333333
# New set of weights found, iteration 217 loss: 1.074988 accuracy 0.4106666666666667
# New set of weights found, iteration 218 loss: 1.0747216 accuracy 0.434
# New set of weights found, iteration 223 loss: 1.0735515 accuracy 0.43266666666666664
# New set of weights found, iteration 235 loss: 1.0730057 accuracy 0.399
# New set of weights found, iteration 259 loss: 1.0730015 accuracy 0.42733333333333334
# New set of weights found, iteration 262 loss: 1.0722715 accuracy 0.427
# New set of weights found, iteration 267 loss: 1.0722584 accuracy 0.422
# New set of weights found, iteration 289 loss: 1.0716438 accuracy 0.43433333333333335
# New set of weights found, iteration 294 loss: 1.0715059 accuracy 0.404
# New set of weights found, iteration 297 loss: 1.0714642 accuracy 0.39666666666666667
# New set of weights found, iteration 298 loss: 1.0714546 accuracy 0.4033333333333333
# New set of weights found, iteration 300 loss: 1.0710276 accuracy 0.4066666666666667
# New set of weights found, iteration 319 loss: 1.0705237 accuracy 0.4106666666666667
# New set of weights found, iteration 467 loss: 1.070348 accuracy 0.4046666666666667
# New set of weights found, iteration 485 loss: 1.0702369 accuracy 0.4156666666666667
# New set of weights found, iteration 508 loss: 1.0702116 accuracy 0.399
# New set of weights found, iteration 513 loss: 1.0699949 accuracy 0.395
# New set of weights found, iteration 613 loss: 1.0699503 accuracy 0.4003333333333333
# New set of weights found, iteration 944 loss: 1.0697238 accuracy 0.4043333333333333
# New set of weights found, iteration 959 loss: 1.0697213 accuracy 0.4026666666666667
# New set of weights found, iteration 1020 loss: 1.0696323 accuracy 0.4026666666666667
# New set of weights found, iteration 1630 loss: 1.0695897 accuracy 0.399
# New set of weights found, iteration 1979 loss: 1.0695422 accuracy 0.39866666666666667
# New set of weights found, iteration 5862 loss: 1.0695285 accuracy 0.4013333333333333
# New set of weights found, iteration 5893 loss: 1.06951 accuracy 0.4
# New set of weights found, iteration 34749 loss: 1.0694945 accuracy 0.399
# New set of weights found, iteration 35802 loss: 1.0694902 accuracy 0.3983333333333333
# New set of weights found, iteration 36450 loss: 1.0694042 accuracy 0.398
# New set of weights found, iteration 50460 loss: 1.069359 accuracy 0.398
# New set of weights found, iteration 74749 loss: 1.0693306 accuracy 0.39566666666666667
# New set of weights found, iteration 100626 loss: 1.0693198 accuracy 0.39866666666666667
# New set of weights found, iteration 196062 loss: 1.0693071 accuracy 0.4

# %%
plt.figure(figsize=(18, 9))
x1 = iter_list[:50]
y1 = accr_list[:50]
plt.plot(x1, y1, label = "Accuracy", linewidth='2')


x2 = iter_list[:50]
y2 = loss_list[:50]
plt.plot(x2, y2, label = "Loss", linewidth='2')


plt.xlabel('Iterations')
plt.ylabel('Value')


plt.title('Spiral Dataset Plot')
plt.legend()
plt.show()

# %%
max(accr_list)
# Out:
# 0.43433333333333335

# %%
min(loss_list)
# Out:
# 1.0693071
